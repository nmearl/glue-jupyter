# %% [markdown]
# ## Exploring the L1448 data in 3D
#
# L1448 is a region within the [Perseus Molecular Cloud](https://en.wikipedia.org/wiki/Perseus_molecular_cloud), a star-formation region located at a distance of 600ly from the Sun. This notebook takes a look at a *spectral cube*, a 3D dataset where two dimensions are the spatial positions on the sky, and the third dimension is e.g. wavelength.
#
# ### About the data
#
# The data is a 13CO spectral cube of the L1448 region. The data can be found in https://github.com/glue-viz/glue-example-data/tree/master/Astronomy/L1448/. For convenience we can use the ``require_data`` function to
# automatically download it here:

# %%
from glue_jupyter.data import require_data
require_data('Astronomy/L1448/l1448_13co.fits')
# Out:
# Successfully downloaded data file to l1448_13co.fits

# %% [markdown]
# ### Starting up the glue Jupyter application

# %% [markdown]
# Let's start up glue and load in the main data file:

# %%
import glue_jupyter as gj
app = gj.jglue()

# %%
cube = app.load_data('l1448_13co.fits')

# %% [markdown]
# ### 3D volume rendering viewer
#
# We can start off by taking a look at the data in the volume viewer:

# %%
app.volshow(data=cube)
# Out:
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# <ipython-input-4-d2dd00882963> in <module>
# ----> 1 app.volshow(data=cube)
#
# ~/projects/glue-jupyter/glue_jupyter/app.py in volshow(self, data, x, y, z, show)
#     397         data = validate_data_argument(self.data_collection, data)
#     398
# --> 399         view = self.new_data_viewer(IpyvolumeVolumeView, data=data, show=show)
#     400
#     401         if x is not None:
#
# ~/projects/glue-jupyter/glue_jupyter/app.py in new_data_viewer(self, *args, **kwargs)
#     101     def new_data_viewer(self, *args, **kwargs):
#     102         show = kwargs.pop('show', True)
# --> 103         viewer = super().new_data_viewer(*args, **kwargs)
#     104         if show:
#     105             viewer.show()
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/glue/core/application_base.py in new_data_viewer(self, viewer_class, data, state)
#      88         if data is not None:
#      89             if isinstance(data, BaseData):
# ---> 90                 result = c.add_data(data)
#      91             elif isinstance(data, Subset):
#      92                 result = c.add_subset(data)
#
# ~/projects/glue-jupyter/glue_jupyter/view.py in add_data(self, data, color, alpha, **layer_state)
#     114         data = validate_data_argument(self._data, data)
#     115
# --> 116         result = super().add_data(data)
#     117
#     118         if not result:
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/glue/viewers/common/viewer.py in add_data(self, data)
#     203             return False
#     204
# --> 205         self._layer_artist_container.append(layer)
#     206         layer.update()
#     207
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/glue/core/layer_artist.py in append(self, artist)
#     273         """Add a LayerArtist to this collection"""
#     274         self.artists.append(artist)
# --> 275         artist.zorder = max(a.zorder for a in self.artists) + 1
#     276         self._notify()
#     277
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/glue_vispy_viewers/common/layer_artist.py in zorder(self, value)
#      12     @zorder.setter
#      13     def zorder(self, value):
# ---> 14         self.state.zorder = value
#      15         self.redraw()  # TODO: determine if this is needed
#      16
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/glue/external/echo/core.py in __setattr__(self, attribute, value)
#     264         super(HasCallbackProperties, self).__setattr__(attribute, value)
#     265         if self.is_callback_property(attribute):
# --> 266             self._notify_global(**{attribute: value})
#     267
#     268     def add_callback(self, name, callback, echo_old=False, priority=0):
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/glue/external/echo/core.py in _notify_global(self, **kwargs)
#     259         if len(kwargs) > 0:
#     260             for callback in self._global_callbacks:
# --> 261                 callback(**kwargs)
#     262
#     263     def __setattr__(self, attribute, value):
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/glue/external/echo/list.py in callback(*args, **kwargs)
#     126
#     127         def callback(*args, **kwargs):
# --> 128             self.notify(instance, wrapped_list, wrapped_list)
#     129
#     130         wrapped_list = CallbackList(callback, value)
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/glue/external/echo/core.py in notify(self, instance, old, new)
#     126             return
#     127         for cback in self._callbacks.get(instance, []):
# --> 128             cback(new)
#     129         for cback in self._2arg_callbacks.get(instance, []):
#     130             cback(old, new)
#
# ~/projects/glue-jupyter/glue_jupyter/widgets/layer_options.py in _update_ui_from_glue_state(self, *args)
#      40         current = self._layer_dropdown.value
#      41
# ---> 42         self._layer_dropdown.options = list(zip(labels, layers))
#      43
#      44         if len(layers) > 0:
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/traitlets/traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1137             new=new_value,
#    1138             owner=self,
# -> 1139             type='change',
#    1140         ))
#    1141
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/ipywidgets/widgets/widget_selection.py in _propagate_options(self, change)
#     214                     self._notify_trait('index', 0, 0)
#     215                 else:
# --> 216                     self.index = 0
#     217             else:
#     218                 self.index = None
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/traitlets/traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1137             new=new_value,
#    1138             owner=self,
# -> 1139             type='change',
#    1140         ))
#    1141
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/ipywidgets/widgets/widget_selection.py in _propagate_index(self, change)
#     233             self.label = label
#     234         if self.value is not value:
# --> 235             self.value = value
#     236
#     237     @validate('value')
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/traitlets/traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1137             new=new_value,
#    1138             owner=self,
# -> 1139             type='change',
#    1140         ))
#    1141
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/projects/glue-jupyter/glue_jupyter/widgets/layer_options.py in _update_layer_options_panel(self, *args)
#      56
#      57         if isinstance(self.viewer._layer_style_widget_cls, dict):
# ---> 58             layer_panel = self.viewer._layer_style_widget_cls[type(layer_artist)](layer_artist.state)
#      59         else:
#      60             layer_panel = self.viewer._layer_style_widget_cls(layer_artist.state)
#
# ~/projects/glue-jupyter/glue_jupyter/ipyvolume/volume/layer_style_widget.py in __init__(self, layer_state)
#      49         link((self.state, 'clamp_max'), (self.widget_clamp_max, 'value'))
#      50
# ---> 51         self.widget_color = ColorPicker(value=self.state.color, description='color')
#      52         link((self.state, 'color'), (self.widget_color, 'value'), color2hex)
#      53
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/traitlets/traitlets.py in __init__(self, *args, **kwargs)
#     995             for key, value in kwargs.items():
#     996                 if self.has_trait(key):
# --> 997                     setattr(self, key, value)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     557
#     558     def set(self, obj, value):
# --> 559         new_value = self._validate(obj, value)
#     560         try:
#     561             old_value = obj._trait_values[self.name]
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/traitlets/traitlets.py in _validate(self, obj, value)
#     589             return value
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#     593             value = self._cross_validate(obj, value)
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/ipywidgets/widgets/trait_types.py in validate(self, obj, value)
#      50                 return value
#      51
# ---> 52         self.error(obj, value)
#      53
#      54
#
# ~/anaconda3/envs/glupyter_dev/lib/python3.7/site-packages/traitlets/traitlets.py in error(self, obj, value)
#     623             e = "The '%s' trait must be %s, but a value of %r was specified." \
#     624                 % (self.name, self.info(), repr_type(value))
# --> 625         raise TraitError(e)
#     626
#     627     def get_metadata(self, key, default=None):
#
# TraitError: The 'value' trait of a ColorPicker instance must be a valid HTML color, but a value of '0.35' <class 'str'> was specified.
